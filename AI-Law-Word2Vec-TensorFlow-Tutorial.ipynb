# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  275.356140137
# Nearest to four: vitis, furthering, helena, chevy, origami, ve, usk, gesture,
# Nearest to while: grizzly, napoli, chee, regulations, ixian, cambrian, briefcase, vw,
# Nearest to b: baron, tsunami, karlsruhe, conscious, darwinian, investigator, guez, convert,
# Nearest to can: hunmin, aosta, cycle, madelyne, speedway, inserting, bin, lugosi,
# Nearest to were: bragi, trajectory, mercalli, brendan, leaking, crucial, iib, rth,
# Nearest to time: swarm, codifying, clinic, html, nebuchadnezzar, finlandization, ranking, spoof,
# Nearest to see: expire, candles, ismail, thom, payment, seaport, excommunicated, dinosauria,
# Nearest to during: democratically, impeachment, marcelo, cabins, astonishment, polled, kirwan, mud,
# Nearest to their: apeiron, marshland, wilhelm, morse, garnet, dining, eubulides, dagbladet,
# Nearest to be: individualized, safeguards, apulia, grappling, govt, ergodic, splitflag, delusion,
# Nearest to often: developers, manoeuvre, qinghai, computability, mobil, acetyl, nationalistic, mas,
# Nearest to six: usd, ulbricht, privatised, chromodynamics, stupid, eradicated, examples, meccans,
# Nearest to which: indexes, rising, loving, innovator, sheila, nikos, dazed, historia,
# Nearest to called: rebellions, shortwave, closed, dostoevsky, lignite, demarcation, mets, tonal,
# Nearest to of: tones, stocking, trevor, ochre, halfback, closures, midwifery, administration,
# Nearest to they: fgc, victor, operand, glorification, easton, protests, quirk, cordova,
# Average loss at step  2000 :  114.079441927
# Average loss at step  4000 :  52.4412475581
# Average loss at step  6000 :  33.4474720664
# Average loss at step  8000 :  23.630321384
# Average loss at step  10000 :  17.8264503915
# Nearest to four: nine, two, three, value, zero, eight, mathbf, surrounding,
# Nearest to while: regulations, homes, major, grizzly, archie, vw, poisons, in,
# Nearest to b: conscious, baron, kicker, convert, metaphysics, tsunami, phi, arise,
# Nearest to can: suicide, cycle, descent, objected, canaris, should, subject, vs,
# Nearest to were: had, coke, stems, opened, crucial, constellations, are, klaus,
# Nearest to time: html, ranking, democratic, day, ignorant, whilst, exposition, wedding,
# Nearest to see: candles, alexis, executed, archie, mathbf, nine, milne, ptolemy,
# Nearest to during: kilgore, first, shorter, impeachment, reformation, strongest, pamphlet, coloured,
# Nearest to their: track, seized, ago, his, atrophy, favor, april, slot,
# Nearest to be: have, socks, risk, champions, conscious, agave, resurgence, married,
# Nearest to often: developers, nationalistic, april, controls, weight, homoerotic, abroad, links,
# Nearest to six: zero, nine, eight, milne, agave, two, mathbf, one,
# Nearest to which: rising, that, junctions, UNK, this, bckgr, successfully, configuration,
# Nearest to called: closed, created, UNK, elephant, buildings, borman, tonal, future,
# Nearest to of: and, in, nine, for, bckgr, the, from, pedro,
# Nearest to they: concentrated, victor, he, abbas, protests, prince, true, dddddd,
# Average loss at step  12000 :  13.6893950619
# Average loss at step  14000 :  11.8306665171
# Average loss at step  16000 :  10.0090453255
# Average loss at step  18000 :  8.41415035129
# Average loss at step  20000 :  7.81839331198
# Nearest to four: eight, nine, two, three, zero, six, seven, five,
# Nearest to while: regulations, homes, major, dasyprocta, rpg, and, on, agouti,
# Nearest to b: d, operatorname, conscious, imperialism, alexandra, tools, one, convert,
# Nearest to can: should, to, may, descent, objected, circ, motif, suicide,
# Nearest to were: are, was, is, had, have, did, klaus, by,
# Nearest to time: ranking, html, day, alphorn, swarm, ignorant, exposition, democratic,
# Nearest to see: alexis, dasyprocta, circ, electra, candles, agouti, two, coke,
# Nearest to during: in, agouti, first, kilgore, of, impeachment, pamphlet, complexion,
# Nearest to their: the, his, its, track, vaccines, dasyprocta, seized, carina,
# Nearest to be: have, is, was, socks, by, resurgence, epistles, mormonism,
# Nearest to often: developers, nationalistic, agouti, circ, also, april, intersecting, ibrahim,
# Nearest to six: nine, eight, seven, zero, three, two, five, four,
# Nearest to which: that, this, agouti, and, rising, UNK, moor, dasyprocta,
# Nearest to called: closed, circ, elephant, buildings, tonal, mindset, shortwave, apatosaurus,
# Nearest to of: and, in, for, agouti, dasyprocta, nine, on, gollancz,
# Nearest to they: he, concentrated, it, which, she, victor, agouti, circ,
# Average loss at step  22000 :  6.95172940457
# Average loss at step  24000 :  6.87172954881
# Average loss at step  26000 :  6.84611389005
# Average loss at step  28000 :  6.36328823137
# Average loss at step  30000 :  5.94168164587
# Nearest to four: eight, three, six, five, two, seven, nine, zero,
# Nearest to while: regulations, nbs, homes, major, and, dasyprocta, aedh, agouti,
# Nearest to b: d, conscious, alexandra, imperialism, operatorname, nicobar, pv, tools,
# Nearest to can: may, should, to, will, could, circ, huge, descent,
# Nearest to were: are, was, had, is, have, did, by, amalthea,
# Nearest to time: ranking, html, day, alphorn, ignorant, exposition, swarm, whilst,
# Nearest to see: electra, alexis, dasyprocta, circ, candles, eight, intervene, airshow,
# Nearest to during: in, first, agouti, kilgore, at, by, after, pathogen,
# Nearest to their: his, the, its, abet, vaccines, dasyprocta, april, seized,
# Nearest to be: have, was, by, is, were, as, are, resurgence,
# Nearest to often: also, developers, nationalistic, which, chalukyas, agouti, circ, it,
# Nearest to six: eight, nine, five, seven, four, three, zero, two,
# Nearest to which: that, this, agouti, hamas, it, also, and, dasyprocta,
# Nearest to called: otimes, closed, circ, UNK, elephant, buildings, shortwave, tonal,
# Nearest to of: and, in, for, nine, dasyprocta, eight, from, agouti,
# Nearest to they: he, it, she, concentrated, airshow, not, there, also,
# Average loss at step  32000 :  6.01753519797
# Average loss at step  34000 :  5.67879223847
# Average loss at step  36000 :  5.79788106406
# Average loss at step  38000 :  5.49749649215
# Average loss at step  40000 :  5.2753630147
# Nearest to four: three, six, five, eight, seven, two, zero, nine,
# Nearest to while: major, homes, in, regulations, nbs, dasyprocta, when, devil,
# Nearest to b: d, operatorname, alexandra, imperialism, conscious, pv, UNK, nicobar,
# Nearest to can: may, should, will, could, would, must, to, aveiro,
# Nearest to were: are, was, had, have, is, did, be, by,
# Nearest to time: ranking, day, aveiro, html, alphorn, whilst, ignorant, swarm,
# Nearest to see: alexis, dasyprocta, circ, intervene, electra, airshow, milne, agouti,
# Nearest to during: in, at, after, first, agouti, by, kilgore, democratically,
# Nearest to their: his, its, the, abet, dasyprocta, lymphoma, vaccines, customary,
# Nearest to be: have, was, by, were, is, are, been, eight,
# Nearest to often: also, developers, commonly, nationalistic, now, which, it, that,
# Nearest to six: eight, four, seven, three, five, nine, zero, one,
# Nearest to which: that, this, agouti, it, also, and, one, hamas,
# Nearest to called: otimes, closed, circ, shortwave, mindset, elephant, UNK, buildings,
# Nearest to of: in, dasyprocta, agouti, for, and, nine, aba, zero,
# Nearest to they: he, it, she, there, not, airshow, we, aveiro,
# Average loss at step  42000 :  5.38359649014
# Average loss at step  44000 :  5.2488696897
# Average loss at step  46000 :  5.27812997746
# Average loss at step  48000 :  5.23804672885
# Average loss at step  50000 :  4.98168217027
# Nearest to four: three, six, five, eight, seven, two, one, zero,
# Nearest to while: when, dasyprocta, and, homes, regulations, agouti, nbs, major,
# Nearest to b: d, operatorname, alexandra, six, eight, imperialism, aleksandar, UNK,
# Nearest to can: may, should, will, could, would, must, to, aveiro,
# Nearest to were: are, was, had, have, is, did, be, amalthea,
# Nearest to time: day, ranking, aveiro, alphorn, html, ignorant, yakovlev, swarm,
# Nearest to see: alexis, dasyprocta, but, electra, intervene, candles, nitrile, circ,
# Nearest to during: in, after, at, first, by, agouti, on, roshan,
# Nearest to their: his, its, the, abet, lymphoma, dasyprocta, vaccines, customary,
# Nearest to be: have, by, were, was, is, been, are, refer,
# Nearest to often: also, commonly, usually, now, developers, nationalistic, which, it,
# Nearest to six: eight, four, seven, three, five, nine, two, one,
# Nearest to which: that, this, also, agouti, it, and, hamas, who,
# Nearest to called: otimes, circ, closed, UNK, and, mindset, shortwave, elephant,
# Nearest to of: in, for, dasyprocta, tavern, agouti, albury, gollancz, abet,
# Nearest to they: he, it, she, there, we, you, not, aveiro,
# Average loss at step  52000 :  5.02677462757
# Average loss at step  54000 :  5.19499647057
# Average loss at step  56000 :  5.06193153477
# Average loss at step  58000 :  5.05009667683
# Average loss at step  60000 :  4.94697213352
# Nearest to four: six, five, eight, three, seven, nine, two, one,
# Nearest to while: when, dasyprocta, grizzly, but, microbats, agouti, is, regulations,
# Nearest to b: d, operatorname, alexandra, UNK, nicobar, pv, michelob, six,
# Nearest to can: may, should, will, could, would, must, to, cannot,
# Nearest to were: are, was, had, have, be, is, did, klaus,
# Nearest to time: day, ranking, aveiro, alphorn, franchisee, almighty, solace, html,
# Nearest to see: but, alexis, electra, pulau, intervene, nitrile, milne, dasyprocta,
# Nearest to during: in, after, at, first, agouti, under, by, when,
# Nearest to their: its, his, the, her, abet, lymphoma, any, dasyprocta,
# Nearest to be: have, was, been, by, were, refer, become, are,
# Nearest to often: also, commonly, usually, now, developers, nationalistic, there, it,
# Nearest to six: eight, four, five, seven, three, nine, zero, wct,
# Nearest to which: this, that, also, agouti, michelob, it, wct, ursus,
# Nearest to called: otimes, closed, UNK, circ, michelob, mindset, shortwave, borman,
# Nearest to of: in, for, dasyprocta, nine, and, wct, agouti, ursus,
# Nearest to they: he, she, we, there, it, you, who, not,
# Average loss at step  62000 :  4.98345972621
# Average loss at step  64000 :  4.86776306313
# Average loss at step  66000 :  4.60392531145
# Average loss at step  68000 :  5.00648972702
# Average loss at step  70000 :  4.89943635678
# Nearest to four: five, six, three, eight, seven, two, nine, one,
# Nearest to while: when, but, dasyprocta, although, microbats, agouti, grizzly, and,
# Nearest to b: d, operatorname, UNK, alexandra, seven, michelob, nuisance, circ,
# Nearest to can: may, should, will, could, would, must, cannot, might,
# Nearest to were: are, was, have, had, be, did, klaus, koh,
# Nearest to time: day, ranking, aveiro, microcebus, boziz, franchisee, alphorn, spoof,
# Nearest to see: thaler, but, electra, nitrile, intervene, pulau, and, alexis,
# Nearest to during: in, after, at, under, first, by, when, agouti,
# Nearest to their: its, his, the, her, some, any, abet, lymphoma,
# Nearest to be: have, been, by, were, become, refer, was, upanija,
# Nearest to often: usually, commonly, also, now, frequently, nationalistic, there, developers,
# Nearest to six: eight, four, five, three, seven, nine, two, one,
# Nearest to which: that, this, also, agouti, michelob, it, wct, ursus,
# Nearest to called: otimes, circ, closed, mindset, michelob, UNK, borman, elephant,
# Nearest to of: dasyprocta, wct, for, agouti, and, tavern, ursus, aba,
# Nearest to they: he, there, we, she, it, you, who, not,
# Average loss at step  72000 :  4.74226023042
# Average loss at step  74000 :  4.81106682432
# Average loss at step  76000 :  4.72062523925
# Average loss at step  78000 :  4.79560801601
# Average loss at step  80000 :  4.79152883112
# Nearest to four: five, six, three, seven, eight, zero, two, nine,
# Nearest to while: when, but, although, dasyprocta, agouti, however, microbats, grizzly,
# Nearest to b: d, operatorname, UNK, alexandra, michelob, circ, albury, thaler,
# Nearest to can: may, should, could, will, would, must, cannot, might,
# Nearest to were: are, was, had, have, be, did, while, koh,
# Nearest to time: day, ranking, microcebus, aveiro, franchisee, almighty, boziz, agouti,
# Nearest to see: thaler, but, nitrile, electra, johnny, alexis, called, pulau,
# Nearest to during: in, after, under, at, by, when, first, agouti,
# Nearest to their: its, his, the, her, some, any, lymphoma, abet,
# Nearest to be: have, been, by, refer, were, become, upanija, was,
# Nearest to often: usually, commonly, now, also, frequently, sometimes, which, nationalistic,
# Nearest to six: five, eight, four, seven, three, nine, two, zero,
# Nearest to which: that, this, also, it, michelob, agouti, still, wct,
# Nearest to called: otimes, circ, michelob, mindset, closed, wct, borman, elephant,
# Nearest to of: wct, dasyprocta, in, agouti, ursus, nine, including, abet,
# Nearest to they: he, there, we, she, you, it, who, not,
# Average loss at step  82000 :  4.76470725906
# Average loss at step  84000 :  4.74274033904
# Average loss at step  86000 :  4.7715089848
# Average loss at step  88000 :  4.7619602766
# Average loss at step  90000 :  4.7251980412
# Nearest to four: five, three, seven, six, eight, two, nine, zero,
# Nearest to while: when, but, although, however, dasyprocta, microbats, agouti, and,
# Nearest to b: d, UNK, operatorname, alexandra, michelob, jiao, nicobar, circ,
# Nearest to can: may, will, should, could, would, must, might, cannot,
# Nearest to were: are, was, have, had, be, while, koh, did,
# Nearest to time: day, ranking, aveiro, microcebus, wedding, boziz, franchisee, but,
# Nearest to see: but, thaler, nitrile, called, electra, albury, alexis, six,
# Nearest to during: in, after, at, under, when, by, first, wct,
# Nearest to their: its, his, the, her, some, any, lymphoma, abet,
# Nearest to be: been, have, were, refer, was, by, become, is,
# Nearest to often: usually, commonly, now, also, sometimes, frequently, still, generally,
# Nearest to six: five, eight, seven, four, three, nine, two, zero,
# Nearest to which: that, this, michelob, also, agouti, but, wct, ursus,
# Nearest to called: otimes, circ, UNK, michelob, mindset, appeals, borman, wct,
# Nearest to of: in, including, agouti, dasyprocta, wct, tavern, aba, for,
# Nearest to they: he, we, there, you, she, it, who, not,
# Average loss at step  92000 :  4.6534336549
# Average loss at step  94000 :  4.7347137059
# Average loss at step  96000 :  4.69975511456
# Average loss at step  98000 :  4.59383042669
# Average loss at step  100000 :  4.69104791296
# Nearest to four: five, six, seven, three, eight, two, zero, nine,
# Nearest to while: when, but, although, however, and, dasyprocta, microbats, were,
# Nearest to b: d, operatorname, alexandra, UNK, michelob, nicobar, circ, eight,
# Nearest to can: may, will, could, would, should, must, might, cannot,
# Nearest to were: are, have, was, had, while, be, is, koh,
# Nearest to time: day, microcebus, aveiro, ranking, almighty, year, franchisee, boziz,
# Nearest to see: thaler, but, nitrile, dasyprocta, electra, albury, milne, vint,
# Nearest to during: after, in, at, under, when, by, wct, through,
# Nearest to their: its, his, the, her, some, lymphoma, any, these,
# Nearest to be: been, have, refer, is, were, by, being, was,
# Nearest to often: usually, commonly, now, also, sometimes, frequently, generally, still,
# Nearest to six: seven, eight, five, four, three, nine, two, wct,
# Nearest to which: that, this, also, michelob, but, agouti, ursus, wct,
# Nearest to called: otimes, circ, michelob, mindset, appeals, closed, wct, borman,
# Nearest to of: dasyprocta, agouti, tavern, including, wct, in, aba, pontificia,
# Nearest to they: he, we, there, you, she, it, not, who,

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# Please install sklearn, matplotlib, and scipy to show embeddings.
# No module named 'typedefs'

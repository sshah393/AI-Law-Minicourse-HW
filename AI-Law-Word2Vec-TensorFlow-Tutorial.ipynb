# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a
# Initialized
# Average loss at step  0 :  283.86932373
# Nearest to for: lorenzo, societies, panamanian, hastily, avoid, implement, jehu, montego,
# Nearest to three: decision, detonated, transsexuals, aura, merger, witnesses, bar, mediocrity,
# Nearest to was: presenting, accidental, idiopathic, longman, sor, forrester, stele, imperfect,
# Nearest to seven: bei, congo, riot, ternary, cadres, perverted, artillery, bethlen,
# Nearest to who: linnaeus, paid, zelazny, languages, cofinality, progeny, nocs, knit,
# Nearest to been: mensch, swerve, orca, koo, rfcs, cumbric, jeter, features,
# Nearest to used: lengthened, forum, feline, hauling, wardens, garis, virginia, meiosis,
# Nearest to called: unconcerned, typed, frontage, echoed, artisans, disqualified, puberty, subgenus,
# Nearest to s: cries, laertius, bithynia, betray, casablanca, miniatures, mountaineer, xv,
# Nearest to also: abundances, postmodern, trigger, afghana, shed, imperceptible, amalthea, gollancz,
# Nearest to system: quae, della, beachcomber, olav, dvds, strat, duckburg, camel,
# Nearest to state: allies, renamo, keswick, subdivided, organize, summarized, arching, preached,
# Nearest to have: bitrates, duration, cristae, donaghy, ape, anesthetics, rosamund, demetrius,
# Nearest to it: approximating, interpretations, electrophoresis, feynman, differentiated, substratum, mocking, contributes,
# Nearest to its: globalsecurity, knit, detectors, manatee, anubis, dunstan, metz, folk,
# Nearest to and: backstory, bucky, bruins, pluriform, aorist, prom, masking, ramesh,
# Average loss at step  2000 :  114.263774224
# Average loss at step  4000 :  52.6334756849
# Average loss at step  6000 :  33.2369973981
# Average loss at step  8000 :  23.2478722467
# Average loss at step  10000 :  17.9192210171
# Nearest to for: in, of, and, to, by, drive, with, avoid,
# Nearest to three: nine, one, four, six, zero, decision, five, two,
# Nearest to was: is, has, are, accidental, omnibus, mosque, while, hubs,
# Nearest to seven: zero, nine, five, eight, agave, austin, two, three,
# Nearest to who: languages, paid, not, altenberg, santos, professed, but, maryland,
# Nearest to been: rfcs, shapes, hakama, features, efficient, crushed, orca, episodes,
# Nearest to used: forum, agave, virginia, wound, replaced, bckgr, displayed, views,
# Nearest to called: extent, being, blore, serving, noting, muslim, tar, artisans,
# Nearest to s: and, phi, rotate, austin, his, zero, carr, alien,
# Nearest to also: afghana, lift, refrigerator, mysore, complementary, efficiency, but, revolt,
# Nearest to system: zero, defended, courier, order, methods, vs, spandau, shepherd,
# Nearest to state: allies, subdivided, preached, welcomed, jewish, assembly, psi, frames,
# Nearest to have: archie, lens, slaves, armenians, belgrade, planets, and, duration,
# Nearest to it: he, a, interpretations, theism, and, husband, nine, contributes,
# Nearest to its: the, markov, least, his, sir, metz, arnold, reprint,
# Nearest to and: in, of, one, phi, UNK, zero, for, the,
# Average loss at step  12000 :  13.9099520648
# Average loss at step  14000 :  11.6773502564
# Average loss at step  16000 :  10.2180733163
# Average loss at step  18000 :  8.51381677103
# Average loss at step  20000 :  7.98356653249
# Nearest to for: and, in, of, by, with, to, on, circ,
# Nearest to three: eight, two, nine, four, six, five, zero, seven,
# Nearest to was: is, has, are, were, by, had, circ, as,
# Nearest to seven: nine, eight, five, zero, four, three, two, six,
# Nearest to who: and, he, not, languages, which, they, treachery, also,
# Nearest to been: shapes, is, rfcs, was, hakama, features, dreams, mutiny,
# Nearest to used: crucifixion, wound, albuquerque, replaced, lengthened, displayed, hearers, agave,
# Nearest to called: and, being, undertaking, puberty, typed, noting, responsible, tar,
# Nearest to s: and, his, zero, dasyprocta, rotate, the, phi, circ,
# Nearest to also: not, gollancz, lift, afghana, would, who, revolt, complementary,
# Nearest to system: della, circ, defended, courier, operatorname, quae, alphorn, order,
# Nearest to state: allies, circ, subdivided, dasyprocta, preached, alexandra, welcomed, jewish,
# Nearest to have: had, be, lens, has, spears, ligands, archie, are,
# Nearest to it: he, this, electrophoresis, feynman, a, interpretations, not, that,
# Nearest to its: the, his, their, markov, dasyprocta, metz, sir, archie,
# Nearest to and: in, dasyprocta, for, or, of, agouti, circ, phi,
# Average loss at step  22000 :  7.09891307521
# Average loss at step  24000 :  6.86781801391
# Average loss at step  26000 :  6.77021251762
# Average loss at step  28000 :  6.37234563625
# Average loss at step  30000 :  5.92478368962
# Nearest to for: in, and, with, of, by, aba, to, appomattox,
# Nearest to three: four, six, eight, five, two, seven, nine, zero,
# Nearest to was: is, has, were, had, by, are, be, as,
# Nearest to seven: eight, nine, five, four, six, zero, three, operatorname,
# Nearest to who: he, and, which, not, they, also, languages, it,
# Nearest to been: was, almighty, shapes, had, dreams, is, rfcs, by,
# Nearest to used: crucifixion, replaced, wound, lengthened, displayed, albuquerque, hearers, advisory,
# Nearest to called: and, puberty, undertaking, being, typed, tar, amalthea, disqualified,
# Nearest to s: and, his, zero, dasyprocta, rotate, two, the, legion,
# Nearest to also: amalthea, not, lift, gollancz, who, which, usually, would,
# Nearest to system: della, circ, operatorname, alphorn, courier, spandau, quae, bo,
# Nearest to state: allies, circ, subdivided, welcomed, dasyprocta, forecast, alexandra, jewish,
# Nearest to have: had, be, has, are, by, ligands, participants, were,
# Nearest to it: he, atacama, this, there, they, that, which, sponsors,
# Nearest to its: the, their, his, dasyprocta, markov, dunstan, metz, archie,
# Nearest to and: or, dasyprocta, in, coke, circ, of, one, phi,
# Average loss at step  32000 :  5.96235230023
# Average loss at step  34000 :  5.68251252615
# Average loss at step  36000 :  5.77944845712
# Average loss at step  38000 :  5.53604400551
# Average loss at step  40000 :  5.25569878888
# Nearest to for: of, with, likud, appomattox, in, and, aba, to,
# Nearest to three: four, six, five, eight, seven, two, one, nine,
# Nearest to was: is, has, were, had, by, be, are, circ,
# Nearest to seven: eight, four, six, five, three, nine, zero, one,
# Nearest to who: he, which, and, also, not, they, isps, it,
# Nearest to been: was, almighty, be, had, shapes, were, swerve, dreams,
# Nearest to used: crucifixion, replaced, found, wound, regarded, albuquerque, almost, displayed,
# Nearest to called: and, undertaking, puberty, rhys, echoed, mishnayot, responsible, being,
# Nearest to s: his, rotate, and, dasyprocta, fashions, phi, the, zero,
# Nearest to also: amalthea, not, lift, which, who, cerebrum, usually, gollancz,
# Nearest to system: della, spandau, alphorn, circ, bo, order, operatorname, quae,
# Nearest to state: circ, allies, subdivided, vdc, dasyprocta, welcomed, alexandra, forecast,
# Nearest to have: had, has, be, are, were, spears, by, ligands,
# Nearest to it: he, there, this, atacama, they, that, which, sponsors,
# Nearest to its: their, the, his, dasyprocta, markov, globalsecurity, peacekeepers, archie,
# Nearest to and: or, dasyprocta, circ, but, in, agouti, zero, phi,
# Average loss at step  42000 :  5.37154042852
# Average loss at step  44000 :  5.23059802759
# Average loss at step  46000 :  5.22828787839
# Average loss at step  48000 :  5.21900422871
# Average loss at step  50000 :  4.9999301672
# Nearest to for: in, of, appomattox, against, with, likud, and, by,
# Nearest to three: four, six, five, two, eight, seven, one, dasyprocta,
# Nearest to was: is, has, were, had, by, be, circ, aveiro,
# Nearest to seven: eight, six, five, four, three, nine, one, kapoor,
# Nearest to who: he, which, and, they, not, isps, also, still,
# Nearest to been: was, be, were, almighty, by, had, shapes, dreams,
# Nearest to used: found, regarded, replaced, crucifixion, considered, wound, displayed, albuquerque,
# Nearest to called: and, UNK, solicitation, undertaking, puberty, echoed, mishnayot, rhys,
# Nearest to s: his, and, dasyprocta, zero, rotate, legion, circ, torah,
# Nearest to also: amalthea, which, not, viridian, usually, still, often, lift,
# Nearest to system: della, spandau, operatorname, alphorn, circ, shepherd, underage, bo,
# Nearest to state: subdivided, allies, circ, vdc, dasyprocta, alexandra, forecast, welcomed,
# Nearest to have: had, has, be, are, were, by, spears, tcp,
# Nearest to it: he, this, there, atacama, they, sponsors, which, not,
# Nearest to its: their, the, his, dasyprocta, markov, pluperfect, peacekeepers, archie,
# Nearest to and: or, but, six, dasyprocta, eight, four, circ, kapoor,
# Average loss at step  52000 :  5.04440679383
# Average loss at step  54000 :  5.19083721757
# Average loss at step  56000 :  5.05055057478
# Average loss at step  58000 :  5.04672309232
# Average loss at step  60000 :  4.95938685703
# Nearest to for: appomattox, in, of, likud, or, by, aba, michelob,
# Nearest to three: four, five, two, six, eight, seven, one, zero,
# Nearest to was: is, has, were, had, by, be, been, became,
# Nearest to seven: eight, six, five, nine, four, three, zero, pulau,
# Nearest to who: he, which, they, isps, also, not, still, she,
# Nearest to been: be, was, were, by, almighty, had, shapes, dreams,
# Nearest to used: ursus, regarded, found, replaced, considered, crucifixion, displayed, wound,
# Nearest to called: undertaking, UNK, puberty, solicitation, ursus, echoed, and, mishnayot,
# Nearest to s: his, dasyprocta, zero, circ, rotate, and, five, ursus,
# Nearest to also: amalthea, which, viridian, still, often, not, usually, lift,
# Nearest to system: della, shepherd, operatorname, ursus, circ, sponsors, spandau, bo,
# Nearest to state: subdivided, circ, allies, dasyprocta, vdc, pulau, jewish, welcomed,
# Nearest to have: had, has, are, were, be, unequivocal, donaghy, by,
# Nearest to it: he, this, there, they, she, atacama, which, not,
# Nearest to its: their, his, the, dasyprocta, markov, pluperfect, our, latinus,
# Nearest to and: or, but, dasyprocta, circ, agouti, pulau, in, coke,
# Average loss at step  62000 :  4.9888291285
# Average loss at step  64000 :  4.85326698023

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
